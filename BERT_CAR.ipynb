# %%
#Sentence based chunking
# !pip install bert-score

import torch
from bert_score import score

# %%
references = [
    "Performance security is a guarantee provided by the contractor to the client/employer to ensure that they will fulfill all the undertaken work as per all the terms and conditions of the contract. It is typically taken in the form of a performance security, which is a financial instrument",
    "The employer keeps 10% of the contract value as performance security.",
    "The contractor shall be liable to pay income tax, withholding tax, super tax, and other taxes on income arising out of the contract.",
    "All taxes applicable to the contractor 28 days prior to the deadline of submission of bids shall be included in the rates and prices.",
    "If the contractor is not on the active tax payer list, they will be ineligible for certain tax benefits and incentives.",
    "All taxes applicable to the contractor 28 days prior to the date of submission will be included in the rates.",
    "The last date of submission of the bid and the day of opening of the bid shall be the same with a minimum gap of 30 minutes",
    "The client can retain the performance security until all the defects before taking over and the conditions of the contract are met.",
    "Bid prices lower than 25% of the Employer's estimates cost of work will be rejected",
    "A bank guarantee is a type of financial instrument provided by a bank or financial institution on behalf of a contractor or bidder in a contract. It acts as a promise from the bank to pay a specified amount to the employer or client if the contractor fails to fulfill their obligations under the contract. The bank guarantee is a form of security for the employer, ensuring that they will be compensated if the contractor defaults on their responsibilities. The bank guarantee typically includes specific conditions and terms that must be met for the guarantee to be activated.",
    "The amount for Bank Guarantee is not mentioned in the document",
    "The amount of Bid Security should be a lump sum figure ranging from one percent (1%) to three percent (3%) of the likely cost of the Works (Employer’s/Engineer’s Estimate) and should not be more than five percent (5%) in any case."
]

candidates_sentences = [
    "Performance security is a guarantee provided by a contractor or bidder to the employer to ensure that they will fulfill all the terms and conditions of a contract. It is usually in the form of a bond or letter of credit and is meant to protect the employer in case the contractor fails to perform as agreed. The performance security amount is typically a percentage of the contract value and is specified in the bidding documents or contract agreement. If the contractor meets all obligations, the performance security is returned at the end of the contract.",

    "The performance security kept by the employer is an amount equal to ten percent (10%) of the amount accepted in the Letter of Acceptance.",

    "The Contractor, Subcontractors, and their employees shall be liable to pay income tax, withholding tax, super tax, and other taxes on income arising out of the Contract. The rates and prices as stated in the contract shall be deemed to cover all such taxes.",

    "Import duties and taxes will be levied on the contractor upon the initial importation of Contractor's Equipment, including essential spare parts. The contractor must post an approved re-export bond or bank guarantee with the customs authorities at the port of entry, valid until the Time for Completion plus six months. The import duties and taxes will be due and payable within 28 days of being invoiced, based on the residual value of the Contractor's Equipment and spare parts to be re-exported, as assessed by the customs authorities.",

    "If the contractor is not on the active taxpayer list, they will be ineligible for the tax benefits related to being recognized as an active taxpayer under the Pakistani Constructor’s Tax Registration requirement.",

    "The last date before which all applicable taxes will be considered is the relevant Date of Completion of the Works or Section as detailed in the Specification, from the date of use and/or occupation by the Contractor.",

    "The bids will be opened at the time, date, and location stipulated in the Bidding Data. The date of receipt and the date of opening of bids should not be too far apart, as specified in the Bidding Data, to ensure timely processing and evaluation of the bids.",

    "The client can retain the performance security until all requirements of Clause 11, Defects After Taking Over, of the Conditions of Contract are fulfilled.",

    "Bid prices lower than 25% below the lower of the Employer’s estimate of the cost of work to be performed under the Contract or the average of other lowest two evaluated substantially responsive Bids will be liable to be rejected.",

    "A bank guarantee is a type of financial instrument provided by a bank or financial institution on behalf of a contractor or bidder in a contract. It acts as a promise from the bank to pay a specified amount to the employer or client if the contractor fails to fulfill their obligations under the contract. The bank guarantee is a form of security for the employer, ensuring that they will be compensated if the contractor defaults on their responsibilities. The bank guarantee typically includes specific conditions and terms that must be met for the guarantee to be activated.",

    "The amount of the bank guarantee is not specified in the provided contexts.",

    "The bid security should be in the form of a Call Deposit Receipt (CDR)/Pay Order or a Security issued by a Scheduled Bank in Pakistan, a foreign bank counter-guaranteed by a Scheduled Bank in Pakistan, or an Insurance Company listed in the Bidding Data with a minimum rating of A(+) for bid prices up to 1000 million PKR and AA for bid prices from 1001 million PKR onwards."
]

# %%
# Calculate BERT-Score
P, R, F1 = score(candidates_sentences, references, lang="en", verbose=True)

# Print the results
for i, (p, r, f) in enumerate(zip(P, R, F1)):
    print(f"Candidate {i+1}:")
    print(f"Precision: {p.item():.4f}")
    print(f"Recall: {r.item():.4f}")
    print(f"F1-Score: {f.item():.4f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# ...

# %%
#Word based chunking
candidates_words = [
    "Performance security is a form of guarantee provided by a contractor to the employer to ensure that the contractor will fulfill all the terms and conditions of the contract. It is typically in the form of a bond or letter of credit and is meant to protect the employer in case the contractor fails to meet their obligations. The performance security is usually issued by a bank or insurance company and is valid for a specified period of time.",

    "The employer keeps an amount equal to ten percent (10%) of the amount accepted in the Letter of Acceptance as performance security.",

    "The Contractor, Subcontractors, and their employees shall be liable to pay income tax, withholding tax, super tax, and other taxes on income arising out of the Contract. The rates and prices as stated in the contract shall be deemed to cover all such taxes.",

    "Taxes applicable to the contractor will be levied by the date of use and/or occupation by the contractor, as detailed in the Specification.",

    "The contractor will be ineligible for tax benefits related to being on the Active Taxpayer List (ATL) of the Federal Board of Revenue (FBR) if they are not registered on the ATL.",

    "The last date before which all applicable taxes will be considered is the relevant Date of Completion of the Works or Section as detailed in the Specification.",

    "Bids will be opened at the time, date, and location stipulated in the Bidding Data. The date of receipt and the date of opening of bids will be determined by the deadline for submission of bids, as specified in the Bidding Data. It is important to note that any bid received after the deadline for submission will be declared late, rejected, and returned unopened to the bidder.",

    "The client can retain the performance security until all requirements of Clause 11, Defects After Taking Over, of the Conditions of Contract are fulfilled.",

    "Bid prices lower than 25% below the lower of the Employer's estimate of the cost of work or the average of other lowest two evaluated substantially responsive bids will be rejected.",

    "A bank guarantee is a type of financial commitment made by a bank on behalf of a customer. It acts as a guarantee to the recipient that the customer will fulfill their obligations under a contract or agreement. In the context of construction projects, a bank guarantee is often required to ensure that the contractor will perform their duties as outlined in the contract. If the contractor fails to meet their obligations, the bank will be responsible for paying a specified sum to the employer. The bank guarantee provides financial security to the employer and helps to mitigate risks associated with the project.",

    "The amount of bank guarantee is not specified in the provided contexts.",

    "The bid security amount should be the same as mentioned in the Invitation for Bids."
]



# Calculate BERT-Score
P, R, F1 = score(candidates_words, references, lang="en", verbose=True)

# Print the results
for i, (p, r, f) in enumerate(zip(P, R, F1)):
    print(f"Candidate {i+1}:")
    print(f"Precision: {p.item():.4f}")
    print(f"Recall: {r.item():.4f}")
    print(f"F1-Score: {f.item():.4f}")
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 37.54 seconds, 0.32 sentences/sec
# Candidate 1:
# Precision: 0.9116
# Recall: 0.9355
# F1-Score: 0.9234
# Candidate 2:
# Precision: 0.9150
# Recall: 0.9578
# F1-Score: 0.9359
# Candidate 3:
# Precision: 0.9192
# Recall: 0.9807
# F1-Score: 0.9490
# Candidate 4:
# Precision: 0.8819
# Recall: 0.8742
# F1-Score: 0.8780
# Candidate 5:
# Precision: 0.8843
# Recall: 0.9326
# F1-Score: 0.9078
# Candidate 6:
# Precision: 0.8520
# Recall: 0.8803
# F1-Score: 0.8659
# Candidate 7:
# Precision: 0.8486
# Recall: 0.8754
# F1-Score: 0.8618
# ...

# %%
#Character based chunking
candidates_character = [
    "Performance security is a form of security provided by the contractor to the employer to ensure that the contractor fulfills all their obligations under the contract. It is usually in the form of a guarantee or bond issued by a bank or insurance company, and it serves as a financial guarantee that the contractor will complete the project according to the terms and conditions of the contract. If the contractor fails to fulfill their obligations, the performance security can be forfeited by the employer.",

    "The performance security to be specified by the employer is an amount equal to ten percent (10%) of the amount accepted in the Letter of Acceptance.",

    "The Contractor, Subcontractors, and their employees shall be liable to pay income tax, withholding tax, super tax, and other taxes on income arising out of the Contract. The rates and prices as stated in the contract shall be deemed to cover all such taxes.",

    "The taxes applicable by the date of completion of the contract will be levied on the contractor.",

    "If the contractor is not on the Active Taxpayer List (ATL) of the Federal Board of Revenue (FBR) in Pakistan, they may be ineligible for certain tax benefits or exemptions that are available to active taxpayers. These benefits could include:\n\n1. Reduced tax rates: Active taxpayers may be eligible for lower tax rates on their income or certain transactions compared to non-active taxpayers.\n2. Tax credits or deductions: Active taxpayers may be able to claim tax credits or deductions for certain expenses or investments that are not available to non-active taxpayers.\n3. Withholding tax exemptions: Active taxpayers may be exempt from certain withholding taxes on their transactions, while non-active taxpayers may have to pay these taxes.\n4. Access to certain tax incentives: Active taxpayers may have access to specific tax incentives or relief measures introduced by the government for promoting compliance and economic activities.\n\nTherefore, not being on the ATL could result in the contractor missing out on these tax benefits and incentives.",

    "The last date before which all applicable taxes will be considered is not specified in the provided contexts.",

    "Bids will be opened at the time, date, and location stipulated in the Bidding Data. The date of receipt and the date of opening of bids should not be too far apart, as specified in the Bidding Data to ensure timely processing and evaluation of the bids.",

    "The client can retain the performance security until all requirements of Clause 11, Defects After Taking Over, of the Conditions of Contract are fulfilled.",

    "Bids with prices lower than 25% below the lower of the Employer’s estimate of the cost of work to be performed under the Contract or the average of other lowest two evaluated substantially responsive Bids will be rejected. This is in accordance with Clause IB.30.1 of the Instructions to Bidders.",

    "A bank guarantee is a type of financial instrument provided by a bank or financial institution on behalf of a contractor or bidder in a contract. It serves as a promise to the employer or project owner that the contractor will fulfill their obligations under the contract. If the contractor fails to meet their obligations, the bank guarantee ensures that the employer will receive compensation up to the specified amount stated in the guarantee. The bank guarantee provides financial security and assurance to the employer that the project will be completed as agreed.",

    "The amount of the bank guarantee in the bid security form is stated as Pak Rupees ____________________________ (Pak Rupees ____________________________).",
    "The bid security should be in the amount stipulated in the Bidding Data. The amount of the bid security is specified in the Bidding Data and should be in PKR or an equivalent amount in a freely convertible currency."
]



# Calculate BERT-Score
P, R, F1 = score(candidates_character, references, lang="en", verbose=True)

# Print the results
for i, (p, r, f) in enumerate(zip(P, R, F1)):
    print(f"Candidate {i+1}:")
    print(f"Precision: {p.item():.4f}")
    print(f"Recall: {r.item():.4f}")
    print(f"F1-Score: {f.item():.4f}")
# Out:
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 52.74 seconds, 0.23 sentences/sec
# Candidate 1:
# Precision: 0.9173
# Recall: 0.9394
# F1-Score: 0.9282
# Candidate 2:
# Precision: 0.8752
# Recall: 0.9160
# F1-Score: 0.8951
# Candidate 3:
# Precision: 0.9192
# Recall: 0.9807
# F1-Score: 0.9490
# Candidate 4:
# Precision: 0.9289
# Recall: 0.9004
# F1-Score: 0.9144
# Candidate 5:
# Precision: 0.8379
# Recall: 0.9265
# F1-Score: 0.8800
# Candidate 6:
# Precision: 0.8719
# Recall: 0.8793
# F1-Score: 0.8756
# Candidate 7:
# Precision: 0.8665
# Recall: 0.8837
# F1-Score: 0.8750
# ...
